# %%
import numpy as np
import pandas as pd

#For this project what I'm trying to do is to clean and transform the data in this dataset by using libraries like numpy and pandas, 
#The followings blocks I'll make some questions to face the problematics in this data set

#Use pandas to read the csv
df = pd.read_csv('/work/data/netflix1.csv')

df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
#Is there any null values?
print(df.isnull().sum())

print('-----------------------')

print('If there any null value?', '\n', 'Answer: ',df.isnull().values.any(), '- Although there is a value that we can count as null known as "Not Given"')
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64
# -----------------------
# If there any null value?
#  Answer:  False - Although there is a value that we can count as null known as "Not Given"

# %%
#Use drop_duplicates method to remove all the duplicates in the dataframe
duplicated = df.drop_duplicates(subset='show_id')

print('Is there any duplicated value?')
print('----------------------------------------------------------------')
print('Dataframe before searching for duplicates: ',df['show_id'].count())
print('Dataframe after searching for duplicates: ',duplicated['show_id'].count())
print('----------------------------------------------------------------')
print('As you can see, there are not duplicates in this dataset')
# Out:
# Is there any duplicated value?
# ----------------------------------------------------------------
# Dataframe before searching for duplicates:  8790
# Dataframe after searching for duplicates:  8790
# ----------------------------------------------------------------
# As you can see, there are not duplicates in this dataset

# %%
print('In the column "listen_in" we have more than one category for some titles, is there a way to remove the other categories and just keep the first one?')
print('Indeed there is a way, by making a new column using the "listed_in" column first category')

#Make a new column and use str.split method to split the information and just take the first part of the split by using the str function positionating it at 0 as first argument
df['category'] = df['listed_in'].str.split(',').str[0]

df
# Out:
# In the column "listen_in" we have more than one category for some titles, is there a way to remove the other categories and just keep the first one?
# Indeed there is a way, by making a new column using the "listed_in" column first category
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# ...

# %%
print("Is there any column that doesn't contribute to give information to the analysis?")
print('Yes, we will remove the columns "show_id", "title" and "listed_in" since they are not useful for the analysis and visualization')

df = df.drop(columns=['show_id','title','listed_in'])
df
# Out:
# Is there any column that doesn't contribute to give information to the analysis?
# Yes, we will remove the columns "show id" and "title" since they are not useful for the analysis and visualization
#          type         director        country  date_added  release_year  \
# 0       Movie  Kirsten Johnson  United States   9/25/2021          2020
# 1     TV Show  Julien Leclercq         France   9/24/2021          2021
# 2     TV Show    Mike Flanagan  United States   9/24/2021          2021
# 3       Movie    Bruno Garotti         Brazil   9/22/2021          2021
# 4       Movie     Haile Gerima  United States   9/24/2021          1993
# ...       ...              ...            ...         ...           ...
# 8785  TV Show        Not Given         Turkey   1/17/2017          2016
# 8786  TV Show        Not Given  United States   9/13/2018          2016
# 8787  TV Show        Not Given       Pakistan  12/15/2016          2012
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ebbeb4ad-3040-45e2-a7db-a2a0c84b25c9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
